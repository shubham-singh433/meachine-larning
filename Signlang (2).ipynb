# %%
# !pip install opencv-python
#conda install numpy
#conda install tensorflow
# Out:
# Requirement already satisfied: opencv-python in c:\users\pragati\anaconda3 2nd\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\pragati\anaconda3 2nd\lib\site-packages (from opencv-python) (1.21.6)

# %%
import cv2
import os
import time
import uuid

# %%
IMAGES_PATH = 'D:\gesture\images'

# %%
labels =['hello','thanks','yes','no']
number_imgs = 15

# %%
for label in labels:
    # !mkdir { 'D:\gesture\images'+ label}
    cap = cv2.VideoCapture(0) 
    print('collecting images for {}'.format(label))
    time.sleep(5)
    for imgnum in range(number_imgs):
        ret, frame = cap.read()
        imagename = os.path.join(IMAGES_PATH, label, label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imagename, frame)
        cv2.imshow('frame', frame)
        time.sleep(2)

        if cv2.waitKey(1) and 0xFF == ord('q'):
             break
    cap.release()
# Out:
# A subdirectory or file D:\gesture\imageshello already exists.
# collecting images for hello
# A subdirectory or file D:\gesture\imagesthanks already exists.
# collecting images for thanks
# A subdirectory or file D:\gesture\imagesyes already exists.
# collecting images for yes
# A subdirectory or file D:\gesture\imagesno already exists.
# collecting images for no
